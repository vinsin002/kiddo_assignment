# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df.sample(10)
# Out:
#      Order ID Total Amount       Created At            Status  \
# 1283   #17051            -  22 Jun 26 21:41         delivered
# 117    #18284            -  30 Jun 26 13:31         delivered
# 7358   #15251            -  12 Jun 26 09:09         cancelled
# 5873   #16798            -  21 Jun 26 12:46         delivered
# 2146   #16124            -  17 Jun 26 23:00         delivered
# 6121   #16545            -  19 Jun 26 23:09         delivered
# 6490   #16142            -  18 Jun 26 08:08         delivered
# 699    #17687            -  26 Jun 26 14:03         delivered
# 8147   #14458            -  05 Jun 26 18:06  reached_delivery
# 5540   #17166            -  23 Jun 26 18:23         delivered
#
#                    Rider Name Rider Contact       Delivery Status  \
# 1283               Unassigned             -  Delayed (+1605 mins)
# 117           Arun Evrecahrge    9368619708               On-Time
# 7358             Sagar Poddar    8750966039               On-Time
# ...

# %%
df.shape
# Out:
# (8717, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8717 entries, 0 to 8716
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Order ID                    8717 non-null   object
#  1   Total Amount                8717 non-null   object
#  2   Created At                  8717 non-null   object
#  3   Status                      8717 non-null   object
#  4   Rider Name                  8717 non-null   object
#  5   Rider Contact               8717 non-null   object
#  6   Delivery Status             8717 non-null   object
#  7   Expected ETA                8717 non-null   object
#  8   Delay Reason                8697 non-null   object
#  9   Scheduled Date              8717 non-null   object
#  10  Scheduled Time              8717 non-null   object
#  11  Packing Duration            8717 non-null   object
#  12  Picked Up Duration          8717 non-null   object
# ...

# %%
df.describe()
# Out:
#        Order ID Total Amount       Created At     Status  Rider Name  \
# count      8717         8717             8717       8717        8717
# unique     4359            2             4037         12         179
# top      #18405            -  20 Jun 26 14:07  delivered  Unassigned
# freq          2         8716                8       7424         846
#
#        Rider Contact Delivery Status Expected ETA Delay Reason Scheduled Date  \
# count           8717            8717         8717         8697           8717
# unique           181             622           91          466             35
# top                -         On-Time   33 minutes            -              -
# freq             846            5640          320         6376           7564
#
#        Scheduled Time Packing Duration Picked Up Duration  \
# count            8717             8717               8717
# unique             20              287                253
# ...

# %%
df.isnull().sum()
# Out:
# Order ID                       0
# Total Amount                   0
# Created At                     0
# Status                         0
# Rider Name                     0
# Rider Contact                  0
# Delivery Status                0
# Expected ETA                   0
# Delay Reason                  20
# Scheduled Date                 0
# Scheduled Time                 0
# Packing Duration               0
# Picked Up Duration             0
# Out for Delivery Duration      0
# Reached Delivery Duration      0
# Reached Delivery Timestamp     0
# Delivered Duration             0
# Delivered Timestamp            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(4358)

# %%
df[df['Order ID'].duplicated()]
# Out:
#      Order ID Total Amount       Created At            Status  \
# 4359   #18405            -  30 Jun 26 23:59         cancelled
# 4360   #18404            -  30 Jun 26 23:54         delivered
# 4361   #18403            -  30 Jun 26 23:54         delivered
# 4362   #18402            -  30 Jun 26 23:53         delivered
# 4363   #18401            -  30 Jun 26 23:51         delivered
# ...       ...          ...              ...               ...
# 8712   #13892            -  01 Jun 26 07:26            packed
# 8713   #13891            -  01 Jun 26 07:01  out_for_delivery
# 8714   #13890            -  01 Jun 26 06:46         delivered
# 8715   #13889            -  01 Jun 26 06:26         delivered
# 8716   #13888            -  01 Jun 26 00:09         delivered
#
#            Rider Name Rider Contact        Delivery Status Expected ETA  \
# 4359       Unassigned             -   Delayed (+3783 mins)   49 minutes
# 4360    sandeep Kiddo    8057924668      Delayed (+4 mins)   60 minutes
# ...

# %%
df['Order ID'].nunique()
# Out:
# 4359

# %%
df[df['Order ID']=='#18402']
# Out:
#      Order ID Total Amount       Created At     Status       Rider Name  \
# 3      #18402            -  30 Jun 26 23:53  delivered  ROSHAN KUMARSFX
# 4362   #18402            -  30 Jun 26 23:53  delivered  ROSHAN KUMARSFX
#
#      Rider Contact     Delivery Status Expected ETA         Delay Reason  \
# 3       8423838078  Delayed (+10 mins)   49 minutes  rider not avilabile
# 4362    8423838078  Delayed (+10 mins)   49 minutes  rider not avilabile
#
#      Scheduled Date Scheduled Time Packing Duration Picked Up Duration  \
# 3        01/07/2026          07:00            3h 6m             4h 38m
# 4362     01/07/2026          07:00            3h 6m             4h 38m
#
#      Out for Delivery Duration Reached Delivery Duration  \
# 3                           3m                       29m
# 4362                        3m                       29m
#
#      Reached Delivery Timestamp Delivered Duration Delivered Timestamp
# ...

# %%
df_final=df.drop_duplicates(keep='first')

# %%
df_final.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_final.drop(df_final[df_final['Delay Reason'] == 'Test order'].index, inplace=True)
# Out:
# /var/folders/md/bl7d8ffd71j23r2c46ylgpxm0000gn/T/ipykernel_8835/1085505269.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.drop(df_final[df_final['Delay Reason'] == 'Test order'].index, inplace=True)

# %%
df_final.drop(df_final[df_final['Status'] == 'cancelled'].index, inplace=True)
# Out:
# /var/folders/md/bl7d8ffd71j23r2c46ylgpxm0000gn/T/ipykernel_8835/4053095564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.drop(df_final[df_final['Status'] == 'cancelled'].index, inplace=True)

# %%
df_final.drop(df_final[df_final['Expected ETA'] == '-'].index, inplace=True)
# Out:
# /var/folders/md/bl7d8ffd71j23r2c46ylgpxm0000gn/T/ipykernel_8835/1710040942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.drop(df_final[df_final['Expected ETA'] == '-'].index, inplace=True)

# %%
df_final.drop(df_final[df_final['Order ID'] == 'Order ID'].index, inplace=True)
# Out:
# /var/folders/md/bl7d8ffd71j23r2c46ylgpxm0000gn/T/ipykernel_8835/1284109224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.drop(df_final[df_final['Order ID'] == 'Order ID'].index, inplace=True)

# %%
df_final.drop(df_final[df_final['Delivered Timestamp']=='-'].index, inplace=True)
# Out:
# /var/folders/md/bl7d8ffd71j23r2c46ylgpxm0000gn/T/ipykernel_8835/574673338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.drop(df_final[df_final['Delivered Timestamp']=='-'].index, inplace=True)

# %%
df_final
# Out:
#      Order ID Total Amount       Created At     Status       Rider Name  \
# 1      #18404            -  30 Jun 26 23:54  delivered    sandeep Kiddo
# 2      #18403            -  30 Jun 26 23:54  delivered        Robin SFX
# 3      #18402            -  30 Jun 26 23:53  delivered  ROSHAN KUMARSFX
# 4      #18401            -  30 Jun 26 23:51  delivered  AKASH THAKURSFX
# 6      #18399            -  30 Jun 26 23:48  delivered    sandeep Kiddo
# ...       ...          ...              ...        ...              ...
# 4349   #13896            -  01 Jun 26 08:28  delivered     ABHIJEET SFX
# 4350   #13895            -  01 Jun 26 07:33  delivered     PAWAN SHARMA
# 4355   #13890            -  01 Jun 26 06:46  delivered      Vikas Kumar
# 4356   #13889            -  01 Jun 26 06:26  delivered    sandeep Kiddo
# 4357   #13888            -  01 Jun 26 00:09  delivered    sandeep Kiddo
#
#      Rider Contact     Delivery Status Expected ETA         Delay Reason  \
# ...

# %%
df_final.to_csv('data_cleaned.csv',index=False)
